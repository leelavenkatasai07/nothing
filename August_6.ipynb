# %%
Matplotlib Module

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.plot(x,y)
plt.grid()
plt.show()

# %%
plot() - keywords
color - linecolor - 'red'/#ccc000
linestyle - line type - '-', '--', ':', '.', '.-.'/'-.-'
[[[ ValueError: '.' is not a valid value for ls; 
supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted' ]]]
linewidth - thickness of the line- 2,3.5,4
marker - symbol -'o','s','^'
marker size - 6, 8, 9, 10
marker color - 'yellow'
marker edge color - 'black'
label = legend - line1, line5

plt.title() - plot title (heading)
plt.xlabel(), ylabel() axis labels
plt.grid() - background
plt.legend() - menu
plt.figure()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='--')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='--', lw=4)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='--', lw=4, marker='o')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='--', lw=4, marker='o', markerfacecolor = 'green')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='--', lw=4, marker='o', markerfacecolor = 'green', markersize=11)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='--', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.title("Line Plot Referal")
plt.xlabel("Years of working")
plt.ylabel("Profit in Millions")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.title("Line Plot Referal", fontsize=16, fontweight='bold', color='blue')
plt.xlabel("Years of working")
plt.ylabel("Profit in Millions")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.title("Line Plot Referal", fontsize=16, fontweight='bold', color='blue')
plt.xlabel("Years of working", fontsize=14)
plt.ylabel("Profit in Millions", fontsize=14)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.title("Line Plot Referal", ha = 'left', va='top', fontsize=16, fontweight='bold', color='blue')
plt.xlabel("Years of working", fontsize=14)
plt.ylabel("Profit in Millions", fontsize=14)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.title("Line Plot Referal", ha = 'left', va='top', fontsize=16, fontweight='bold', color='blue')
plt.xlabel("Years of working", fontsize=14)
plt.ylabel("Profit in Millions", fontsize=14)
plt.gca().set_facecolor('lightblue')
plt.gcf().set_facecolor('lightgrey')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', ls='-.', lw=4, marker='o', markerfacecolor = 'green', markersize=7, markeredgecolor = 'black')
plt.title("Line Plot Referal", ha = 'left', va='top', fontsize=16, fontweight='bold', color='blue')
plt.xlabel("Years of working", fontsize=14)
plt.ylabel("Profit in Millions", fontsize=14)
plt.gca().set_facecolor('lightblue')
plt.gcf().set_facecolor('lightgrey')
plt.grid(True, linestyle='', lw = 3, alpha=0.7)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

try:
    df = pd.read_csv('hospital_data.csv')
    cost_series = df['Bill']
    date_series = df['Admission_Date']
    print("\n Original Bill series: ")
    print(cost_series)
    print("\n Original Date series: ")
    print(date_series)

# user input for cleaning and plotting
    print('\n Fill the Missing Bill Value with median before plotting? (yes/no) : ')
    fill_confirm = input().strip().lower()
    print("convert Admisssion date DD/MM/YYYY for display? (yes/no) : ")
    date_format_confirm = input().strip().lower()

# perform clean bill missing values
    if fill_confirm == 'yes':
        median_cost = cost_series.median()
        cleaned_cost_series = cost_series.fillna(median_cost)
        print(cleaned_cost_series)
    else:
        print('\n No changes to medical cost')

# convert admission date to datetime
    cleaned_date_series = pd.to_datetime(date_series, format='%Y-%m-%d', errors='coerce')
    if date_format_confirm == 'yes':
        display_dates = cleaned_date_series.dt.strftime('%d-%m-%Y')
    else:
        display_dates = cleaned_date_series

# plot
    plt.figure(figsize=(10,6))
    plt.plot(cleaned_date_series, cleaned_cost_series, marker='o', ls='-', color='blue')
    plt.title("Medical Cost Over Admission Dates")
    plt.xlabel("Admission Date")
    plt.ylabel('Medical Cost ($)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# update and save
    if fill_confirm == 'yes' or date_format_confirm == 'yes':
        df['Bill']= cleaned_cost_series
        df['Admission_date'] = display_dates if date_format_confirm == 'yes' else cleaned_date_series
        df.to_csv('hospital_data.csv', index= False)
        print("\n Updated csv saved to 'hospital_data.csv'.")
    else:
        print('\n Not updated.')
except FileNotFoundError:
    print("Error: 'hospital_data.csv' not found.")
except ValueError as e:
    print(f"Error: Invalid date format ({e}).")
# Out:
#  Original Bill series:
# 0      7000.8
# 1     76000.0
# 2    500000.0
# 3    200000.0
# 4     80000.0
# 5     80000.0
# Name: Bill, dtype: float64
#
#  Original Date series:
# 0    2025-01-15
# 1    2025-02-10
# 2    2025-03-03
# 3    2025-01-22
# 4    2025-04-06
# 5    2025-08-04
# Name: Admission_Date, dtype: object
#
#  Fill the Missing Bill Value with median before plotting? (yes/no) :
#  yes
# convert Admisssion date DD/MM/YYYY for display? (yes/no) :
#  yes
# 0      7000.8
# 1     76000.0
# 2    500000.0
# 3    200000.0
# 4     80000.0
# 5     80000.0
# Name: Bill, dtype: float64
#  Updated csv saved to 'hospital_data.csv'.
